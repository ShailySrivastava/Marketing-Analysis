# %% [markdown]
# <a href="https://colab.research.google.com/github/ShailySrivastava/README/blob/main/Task_3_Descriptive_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Data_set 2 - Copy.csv')

# %%
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
df.age
# Out:
# 0     34
# 1     23
# 2     30
# 3     22
# 4     24
# 5     24
# 6     27
# 7     21
# 8     35
# 9     31
# 10    35
# 11    29
# 12    21
# 13    28
# 14    25
# 15    27
# 16    28
# 17    27
# 18    29
# 19    26
# 20    29
# 21    24
# 22    27
# 23    25
# 24    26
# 25    32
# 26    26
# 27    31
# 28    29
# 29    34
# 30    27
# 31    31
# 32    27
# 33    26
# 34    27
# 35    30
# 36    30
# 37    25
# 38    31
# 39    29
# Name: age, dtype: int64

# %%
df.age.unique()
# Out:
# array([34, 23, 30, 22, 24, 27, 21, 35, 31, 29, 28, 25, 26, 32])

# %%
df.age.value_counts()
# Out:
# age
# 27    7
# 29    5
# 31    4
# 26    4
# 30    3
# 24    3
# 25    3
# 34    2
# 21    2
# 35    2
# 28    2
# 23    1
# 22    1
# 32    1
# Name: count, dtype: int64

# %%
print(df.describe())
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
df.dropna(inplace=True)

# %%
perc = [.20, .40, .60, .80]

# %%
include = ['object', 'float', 'int']

# %%
desc = df.describe(percentiles=perc, include=include)

# %%
desc
# Out:
#        gender        age Investment_Avenues  Mutual_Funds  Equity_Market  \
# count      40  40.000000                 40     40.000000      40.000000
# unique      2        NaN                  2           NaN            NaN
# top      Male        NaN                Yes           NaN            NaN
# freq       25        NaN                 37           NaN            NaN
# mean      NaN  27.800000                NaN      2.550000       3.475000
# std       NaN   3.560467                NaN      1.197219       1.131994
# min       NaN  21.000000                NaN      1.000000       1.000000
# 20%       NaN  25.000000                NaN      2.000000       3.000000
# 40%       NaN  27.000000                NaN      2.000000       3.000000
# 50%       NaN  27.000000                NaN      2.000000       4.000000
# 60%       NaN  29.000000                NaN      2.000000       4.000000
# 80%       NaN  31.000000                NaN      3.000000       4.000000
# ...

# %%
df.dropna(inplace=True)

# %%
desc = df["age"].describe()

# %%
desc
# Out:
# count    40.000000
# mean     27.800000
# std       3.560467
# min      21.000000
# 25%      25.750000
# 50%      27.000000
# 75%      30.000000
# max      35.000000
# Name: age, dtype: float64

# %%
age_mean = df["age"].mean()

# %%
age_mean
# Out:
# 27.8

# %%
age_mode = df["age"].mode()

# %%
age_mode
# Out:
# 0    27
# Name: age, dtype: int64

# %%
age_std = df["age"].std()

# %%
age_std
# Out:
# 3.560466693696639

# %%
age_median = df["age"].median()

# %%
age_median
# Out:
# 27.0
